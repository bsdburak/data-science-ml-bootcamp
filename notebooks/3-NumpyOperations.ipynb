# %%
import numpy as np

# %%
array = np.random.randint(1, 100, 10)

# %%
array
# Out:
# array([73, 50,  7, 20, 84, 58, 57, 92, 54, 27], dtype=int32)

# %%
array < 25
# Out:
# array([False, False,  True,  True, False, False, False, False, False,
#        False])

# %%
array[array < 25]
# Out:
# array([ 7, 20], dtype=int32)

# %%
# transpose and reshape

# %%
matrix_array = np.array([[1, 2], [3, 4], [5, 6]])

# %%
matrix_array
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
matrix_array.T # = matrix_array.transpose()
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %% [raw]
# reshape_array = np.random.random((6, 1))

# %%
reshape_array
# Out:
# array([[0.86128247],
#        [0.43056581],
#        [0.27548414],
#        [0.89754375],
#        [0.19731931],
#        [0.39857385]])

# %%
reshape_array.reshape(3, 2)
# Out:
# array([[0.86128247, 0.43056581],
#        [0.27548414, 0.89754375],
#        [0.19731931, 0.39857385]])

# %%
# math example
# 3x + 6y = 21 and 6x + y = 20

# %%
A = np.array([[3, 6], [6, 1]])

# %%
B = np.array([21, 20])

# %%
result = np.linalg.solve(A, B)

# %%
result
# Out:
# array([3., 2.])
